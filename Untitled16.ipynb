# %%
# Out:
# mean is : 16.0

# %%
import numpy as np
lst = [1,4,7,2,6]
mean = np.mean(lst)
print("mean is :",mean)
print("Variance is",np.var(lst))
print("Standard Deviation is:", np.sqrt(np.var(lst)))
# Out:
# mean is : 4.0
# Variance is 5.2
# Standard Deviation is: 2.280350850198276

# %%
import numpy as np
lst = [0,0,0,0]
mean = np.mean(lst)
print("mean is :",mean)
print("Variance is",np.var(lst))
print("Standard Deviation is:", np.sqrt(np.var(lst)))
# Out:
# mean is : 0.0
# Variance is 0.0
# Standard Deviation is: 0.0

# %%
np.sqrt(np.var(lst))
# Out:
# 1.0954451150103321
