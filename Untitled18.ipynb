# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

# %%
df = pd.read_csv('/content/drive/MyDrive/Kaggle/toy_dataset.csv')
df.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %%
data = df[['Age','Income']]

# %%
data
# Out:
#         Age    Income
# 0        41   40367.0
# 1        54   45084.0
# 2        42   52483.0
# 3        40   40941.0
# 4        46   50289.0
# ...     ...       ...
# 149995   48   93669.0
# 149996   25   96748.0
# 149997   26  111885.0
# 149998   25  111878.0
# 149999   37   87251.0
#
# [150000 rows x 2 columns]

# %%
scaler = MinMaxScaler()
df = scaler.fit_transform(data)

# %%
data = df[:15000,]

# %%
data
# Out:
# array([[0.4       , 0.23070001],
#        [0.725     , 0.25722818],
#        [0.425     , 0.29883978],
#        ...,
#        [0.15      , 0.32769064],
#        [0.175     , 0.32708325],
#        [0.9       , 0.3275163 ]])

# %%
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,7))
plt.title('customer Dentogram')
dend = shc.dendrogram(shc.linkage(data, method='ward'))
# Out:
# Error in callback <function flush_figures at 0x7f4ae86a4950> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
# ...

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean',
                                  linkage='ward')
cluster.fit_predict(data)
# Out:
# array([4, 3, 2, ..., 0, 0, 1])

# %%
fig = plt.figure(figsize=(10,7))
plt.scatter(data[:,0], data[:,1], c = cluster.labels_,cmap='rainbow')
plt.xlabel('age')
plt.ylabel('income')
plt.show()

# %%
df = pd.read_csv('/content/drive/MyDrive/Kaggle/toy_dataset.csv')
data = df[['Age','Income']]

scaler = MinMaxScaler()
df = scaler.fit_transform(data)

cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean',
                                  linkage='ward')
cluster.fit_predict(df)

# %%
fig = plt.figure(figsize=(10,7))
plt.scatter(data[:,0], data[:,1], c = cluster.labels_,cmap='rainbow')
plt.xlabel('age')
plt.ylabel('income')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-08e7e3e4989c> in <module>()
#       1
# ----> 2 fig = plt.figure(figsize=(10,7))
#       3 plt.scatter(data[:,0], data[:,1], c = cluster.labels_,cmap='rainbow')
#       4 plt.xlabel('age')
#       5 plt.ylabel('income')
#
# NameError: name 'plt' is not defined
